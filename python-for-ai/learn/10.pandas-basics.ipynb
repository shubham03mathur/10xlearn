# %% [markdown]
# # Pandas Basics
#
# Pandas is the most essential library for data manipulation and analysis in Python. It provides the `DataFrame` object, which is basically a table (like an Excel spreadsheet) that we can manipulate easily.

# %% [markdown]
# ### Creating and Viewing DataFrames
#
# You can create a DataFrame from a dictionary or by loading a CSV file.

# %%
import pandas as pd

data = {
    "Name": ["Alice", "Bob", "Charlie", "David"],
    "Age": [25, 30, 35, 40],
    "City": ["New York", "London", "Paris", "Tokyo"],
    "Score": [85, 90, 95, 80]
}

df = pd.DataFrame(data)

print(df.head())
print("\nSummary Statistics:")
print(df.describe())

# %% [markdown]
# ### Selecting and Filtering Data
#
# We can select columns, rows, or filtered results easily.

# %%
# Selecting a single column
print("Age Column:")
print(df["Age"])

# Filtering: People older than 30
older_than_30 = df[df["Age"] > 30]
print("\nPeople older than 30:")
print(older_than_30)

# %% [markdown]
# ### Reading CSV Files
#
# In almost all AI projects, the data starts in a CSV file. Pandas makes it simple to load this data into a DataFrame.

# %%
# Example of how to read a CSV (pseudo-code as no file is provided)
# df = pd.read_csv("dataset.csv")

print("Pandas is ready to process your data.")
