# %% [markdown]
# # Evaluation Metrics
#
# How do we know if our model is actually good? We use **Metrics** to quantify the performance of our model. Different problems require different metrics.

# %% [markdown]
# ### Classification Metrics
# When predicting categories, common metrics include:

# %% [markdown]
# - **Accuracy**: The percentage of correct predictions.
# - **Precision**: Out of all predicted positives, how many were actually positive?
# - **Recall**: Out of all actual positives, how many did we correctly identify?
# - **F1-Score**: The harmonic mean of Precision and Recall (good for imbalanced data).

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

y_true = [0, 1, 1, 0, 1, 1]
y_pred = [0, 1, 0, 0, 1, 1]

print(f"Accuracy: {accuracy_score(y_true, y_pred):.2f}")
print(f"Precision: {precision_score(y_true, y_pred):.2f}")
print(f"Recall: {recall_score(y_true, y_pred):.2f}")
print(f"F1-Score: {f1_score(y_true, y_pred):.2f}")

# %% [markdown]
# ### Regression Metrics
# When predicting continuous numbers, we use:

# %% [markdown]
# - **Mean Squared Error (MSE)**: The average of the squares of the errors.
# - **Root Mean Squared Error (RMSE)**: The square root of MSE (same units as the target variable).
# - **R-squared**: How much of the variance in the data is explained by the model.

# %%
from sklearn.metrics import mean_squared_error, r2_score

y_true = [100, 200, 300, 400]
y_pred = [110, 190, 300, 420]

print(f"MSE: {mean_squared_error(y_true, y_pred):.2f}")
print(f"R-squared: {r2_score(y_true, y_pred):.2f}")
