# %% [markdown]
# # What are the variables?
#
# Variables is like labeled container or box which you can use to store data. you can give it a name/label and assign it a value, later on the same value can be accessed with the label/name.
#
# Here’s how to create a variable:

# %%
user_name = "shubham"
portfolio = "shubhammathur.dev"
isAdmin = True
user_id=12345
roles=[]
permissions={}

# %% [markdown]
# As described above, we can declare the variables and can also reuse them to retrieve the value.

# %%
print(user_name)
